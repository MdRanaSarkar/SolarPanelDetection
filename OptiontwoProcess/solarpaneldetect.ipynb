# %%
import numpy as np
import pandas as pd
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
import keras
from tensorflow.keras.utils import to_categorical

# %matplotlib inline
from matplotlib.colors import ListedColormap
import warnings
warnings.filterwarnings("ignore")

plt.close()

# %%
dir_train_images  = './training/'
dir_test_images   = './testing/'
dir_train_labels  = 'labels_training.csv'
dir_test_ids      = 'sample_submission.csv'

# %%
# from kyle's code load data
def load_data(dir_data, dir_labels, training=True):
    ''' Load each of the image files into memory 

    While this is feasible with a smaller dataset, for larger datasets,
    not all the images would be able to be loaded into memory

    When training=True, the labels are also loaded
    '''
    labels_pd = pd.read_csv(dir_labels)
    ids       = labels_pd.id.values
    data      = []
    for identifier in ids:
        fname     = dir_data + identifier.astype(str) + '.tif'
        image     = mpl.image.imread(fname)
        data.append(image)
    data = np.array(data) # Convert to Numpy array
    if training:
        labels = labels_pd.label.values
        return data, labels
    else:
        return data, ids

# %%
# from kyle's code draw roc
def plot_roc(labels, prediction_scores, title='ROC'):
    fpr, tpr, _ = metrics.roc_curve(labels, prediction_scores, pos_label=1)
    auc = metrics.roc_auc_score(labels, prediction_scores)
    legend_string = 'AUC = {:0.3f}'.format(auc)
       
    plt.figure(figsize=(10,8))
    plt.plot([0,1],[0,1],'--', color='gray', label='Chance')
    plt.plot(fpr, tpr, label=legend_string, color = 'red')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.grid()
    plt.axis('square')
    plt.title(title)
    plt.legend()
    plt.tight_layout()

# %%
# trainning with y labels
data, ylabel = load_data(dir_train_images, dir_train_labels, training=True)
# test dataset for kaggle
testd, ids = load_data(dir_test_images, dir_test_ids, training=False) 

data = data.astype('float32')
data /= 255
testd = testd.astype('float32')
testd /= 255

input_shape = 101, 101, 3

# %%
# split the trainning data into 8-2 ratio of trainning and validation
xtr, xva, ytr, yva = train_test_split(data, ylabel, test_size=0.2, random_state=423)

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout

# build the CNN model
cnn_model = Sequential()

# 1st layer
cnn_model.add(Conv2D(32, (3, 3), input_shape = input_shape, activation = 'relu', padding = 'same'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))

# 2nd layer
cnn_model.add(Conv2D(64, (3, 3), activation = 'relu', padding = 'same'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))

# 3rd layer
# start throw away half of the data out
cnn_model.add(Conv2D(128, (3, 3), activation = 'relu', padding = 'same'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
cnn_model.add(Dropout(0.5))

# 4th layer
cnn_model.add(Conv2D(256, (3, 3), activation = 'relu', padding = 'same'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
cnn_model.add(Dropout(0.5))

# 5th layer
cnn_model.add(Conv2D(128, (3, 3), activation = 'relu', padding = 'same'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
cnn_model.add(Dropout(0.5))

# transform
cnn_model.add(Flatten())
cnn_model.add(Dense(units = 64, activation = 'relu'))
cnn_model.add(Dense(units = 1, activation = 'sigmoid'))

cnn_model.compile(loss=keras.losses.binary_crossentropy,
          optimizer=keras.optimizers.Adam(),
          metrics=['accuracy'])

# %%
cnn_fit = cnn_model.fit(data, ylabel, batch_size=100,epochs=50, verbose=1,validation_data=(xva, yva))
# Out:
# Epoch 1/50
# 15/15 [==============================] - 28s 993ms/step - loss: 0.6651 - accuracy: 0.6596 - val_loss: 0.6364 - val_accuracy: 0.7100
# Epoch 2/50
# 15/15 [==============================] - 14s 946ms/step - loss: 0.6413 - accuracy: 0.6716 - val_loss: 0.6383 - val_accuracy: 0.7100
# Epoch 3/50
# 15/15 [==============================] - 15s 981ms/step - loss: 0.6451 - accuracy: 0.6736 - val_loss: 0.6436 - val_accuracy: 0.7100
# Epoch 4/50
# 15/15 [==============================] - 15s 974ms/step - loss: 0.6416 - accuracy: 0.6736 - val_loss: 0.6504 - val_accuracy: 0.7100
# Epoch 5/50
# 15/15 [==============================] - 14s 959ms/step - loss: 0.6516 - accuracy: 0.6526 - val_loss: 0.6291 - val_accuracy: 0.7100
# Epoch 6/50
# 15/15 [==============================] - 14s 959ms/step - loss: 0.6468 - accuracy: 0.6490 - val_loss: 0.6122 - val_accuracy: 0.7100
# Epoch 7/50
# 15/15 [==============================] - 14s 956ms/step - loss: 0.6313 - accuracy: 0.6703 - val_loss: 0.6296 - val_accuracy: 0.7100
# Epoch 8/50
# 15/15 [==============================] - 15s 975ms/step - loss: 0.6324 - accuracy: 0.6689 - val_loss: 0.6585 - val_accuracy: 0.7100
# Epoch 9/50
# 15/15 [==============================] - 15s 1s/step - loss: 0.6437 - accuracy: 0.6695 - val_loss: 0.5925 - val_accuracy: 0.7100
# Epoch 10/50
# 15/15 [==============================] - 15s 1s/step - loss: 0.6186 - accuracy: 0.6568 - val_loss: 0.5591 - val_accuracy: 0.7100
# Epoch 11/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.6044 - accuracy: 0.6703 - val_loss: 0.5385 - val_accuracy: 0.7233
# Epoch 12/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.5797 - accuracy: 0.6963 - val_loss: 0.5222 - val_accuracy: 0.7500
# Epoch 13/50
# 15/15 [==============================] - 15s 989ms/step - loss: 0.5641 - accuracy: 0.7063 - val_loss: 0.5663 - val_accuracy: 0.6933
# Epoch 14/50
# 15/15 [==============================] - 15s 1s/step - loss: 0.5617 - accuracy: 0.7017 - val_loss: 0.5332 - val_accuracy: 0.7767
# Epoch 15/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.5347 - accuracy: 0.7236 - val_loss: 0.4986 - val_accuracy: 0.7567
# Epoch 16/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.5351 - accuracy: 0.7290 - val_loss: 0.4734 - val_accuracy: 0.7967
# Epoch 17/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.5149 - accuracy: 0.7462 - val_loss: 0.4679 - val_accuracy: 0.7767
# Epoch 18/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.5194 - accuracy: 0.7499 - val_loss: 0.4579 - val_accuracy: 0.8233
# Epoch 19/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.4638 - accuracy: 0.7837 - val_loss: 0.3997 - val_accuracy: 0.8133
# Epoch 20/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.4515 - accuracy: 0.7871 - val_loss: 0.5352 - val_accuracy: 0.6967
# Epoch 21/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.4893 - accuracy: 0.7647 - val_loss: 0.4344 - val_accuracy: 0.7900
# Epoch 22/50
# 15/15 [==============================] - 15s 1s/step - loss: 0.4707 - accuracy: 0.7697 - val_loss: 0.3700 - val_accuracy: 0.8567
# Epoch 23/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.4351 - accuracy: 0.8073 - val_loss: 0.5106 - val_accuracy: 0.7200
# Epoch 24/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.4741 - accuracy: 0.7749 - val_loss: 0.4072 - val_accuracy: 0.8500
# Epoch 25/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.4542 - accuracy: 0.7835 - val_loss: 0.3573 - val_accuracy: 0.8467
# Epoch 26/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.4298 - accuracy: 0.8114 - val_loss: 0.3802 - val_accuracy: 0.8333
# Epoch 27/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.4093 - accuracy: 0.8048 - val_loss: 0.3577 - val_accuracy: 0.8467
# Epoch 28/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.3983 - accuracy: 0.8290 - val_loss: 0.3418 - val_accuracy: 0.8567
# Epoch 29/50
# 15/15 [==============================] - 15s 1s/step - loss: 0.3831 - accuracy: 0.8187 - val_loss: 0.3490 - val_accuracy: 0.8433
# Epoch 30/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.4333 - accuracy: 0.7975 - val_loss: 0.3328 - val_accuracy: 0.8633
# Epoch 31/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.3769 - accuracy: 0.8345 - val_loss: 0.2679 - val_accuracy: 0.8967
# Epoch 32/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.3490 - accuracy: 0.8379 - val_loss: 0.2385 - val_accuracy: 0.9300
# Epoch 33/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.2807 - accuracy: 0.8828 - val_loss: 0.2141 - val_accuracy: 0.9233
# Epoch 34/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.3041 - accuracy: 0.8716 - val_loss: 0.2050 - val_accuracy: 0.9433
# Epoch 35/50
# 15/15 [==============================] - 15s 1s/step - loss: 0.2723 - accuracy: 0.8965 - val_loss: 0.2556 - val_accuracy: 0.8833
# Epoch 36/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.2724 - accuracy: 0.8835 - val_loss: 0.1989 - val_accuracy: 0.9467
# Epoch 37/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.2368 - accuracy: 0.9059 - val_loss: 0.1375 - val_accuracy: 0.9700
# Epoch 38/50
# 15/15 [==============================] - 18s 1s/step - loss: 0.2203 - accuracy: 0.9141 - val_loss: 0.1649 - val_accuracy: 0.9433
# Epoch 39/50
# 15/15 [==============================] - 17s 1s/step - loss: 0.2029 - accuracy: 0.9204 - val_loss: 0.1168 - val_accuracy: 0.9700
# Epoch 40/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.1514 - accuracy: 0.9443 - val_loss: 0.1256 - val_accuracy: 0.9567
# Epoch 41/50
# 15/15 [==============================] - 15s 1s/step - loss: 0.1736 - accuracy: 0.9379 - val_loss: 0.1322 - val_accuracy: 0.9500
# Epoch 42/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.1488 - accuracy: 0.9367 - val_loss: 0.1097 - val_accuracy: 0.9533
# Epoch 43/50
# 15/15 [==============================] - 15s 1s/step - loss: 0.1838 - accuracy: 0.9281 - val_loss: 0.1560 - val_accuracy: 0.9700
# Epoch 44/50
# 15/15 [==============================] - 15s 1s/step - loss: 0.2055 - accuracy: 0.9176 - val_loss: 0.1128 - val_accuracy: 0.9767
# Epoch 45/50
# 15/15 [==============================] - 15s 1s/step - loss: 0.1640 - accuracy: 0.9335 - val_loss: 0.1178 - val_accuracy: 0.9567
# Epoch 46/50
# 15/15 [==============================] - 15s 1s/step - loss: 0.1067 - accuracy: 0.9632 - val_loss: 0.0870 - val_accuracy: 0.9733
# Epoch 47/50
# 15/15 [==============================] - 15s 1s/step - loss: 0.1089 - accuracy: 0.9690 - val_loss: 0.0502 - val_accuracy: 0.9933
# Epoch 48/50
# 15/15 [==============================] - 16s 1s/step - loss: 0.1191 - accuracy: 0.9531 - val_loss: 0.0473 - val_accuracy: 0.9833
# Epoch 49/50
# 15/15 [==============================] - 15s 1s/step - loss: 0.0855 - accuracy: 0.9633 - val_loss: 0.1050 - val_accuracy: 0.9633
# Epoch 50/50
# 15/15 [==============================] - 15s 1s/step - loss: 0.1300 - accuracy: 0.9495 - val_loss: 0.0645 - val_accuracy: 0.9800

# %%
# plot ROC
pred = cnn_model.predict(data) 
plot_roc(ylabel, pred)

# %%
pred1  = pred.reshape((pred.shape[0],))
roc_file = pd.DataFrame({'y':    ylabel,'pred':  pred1})
roc_file.to_csv('finalresultsubmission.csv',
                           columns=['y','pred'],
                           index=False)
